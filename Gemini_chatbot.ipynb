# %% [markdown]
# <a href="https://colab.research.google.com/github/imsuru/Gemini-powered-chatbot/blob/main/Gemini_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install google-genai

# %%
from google import genai
import os

# %%
api_key = 'place your own api key'
client = genai.Client(api_key=api_key)

# %%
print("-- genAI tester-- type exit to quit")

while True:
  user_prompt = input("\nUser:")

  if user_prompt.lower() in ['exit', 'quit']:
    break

  try:
    response = client.models.generate_content(
        model = 'gemini-2.5-flash',
        contents = user_prompt
    )
    print(f"Ai:{response.text}")
  except Exception as e:
      print(f"Error:{e}")
# Out:
# -- genAI tester-- type exit to quit
#
# User:hi tell me about google in 10 words
# Ai:Organizes world's information, makes it universally accessible, useful, and profitable.
#
# User:exit
